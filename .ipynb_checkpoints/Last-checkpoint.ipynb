# %%
from base import base
from collect import collect
#from connect_site import connect
#from cleaning import cleaning
from proxies import proxies
from data_df import data_df
import pandas as pd

options = proxies()

# %%
f = base()
# Out:
# Сhoose a category:
# 1) Bolig til salgs
# 2) Nye boliger
# 3) Tomter
# 4) Fritidsbolig til salgs
# 5) Fritidstomter
# 6) Bolig til leie
# 7) Hjerterom - Bolig til leie
# 8) Næringseiendom til salgs
# 9) Næringseiendom til leie
# 10) Næringstomter
# 11) Bedrifter til salgs
# (pick number)
# 1
# Do you want to select 1 - "cities" or 2 - "city with radius"? (pick number)
# 2
# Choose the area and radius(from 200 to 100000 meter) (use one space between)
# Bergen 2000

# %%
data = collect(*f, options=options)
# Out:
# connection successful
# All is collected!

# %%
all_data = data_df(data, f[0])

# %%
#%%writefile cleaning.py
import pandas as pd
import numpy as np

#cleaning data def
def cleaning(all_data): #from data_df
    df = all_data.drop_duplicates()
    pd.set_option('display.max_colwidth', None)
    
    #for price
    if 'price' in df.columns:
        try:
            df['price'] = df['price'].str.split('-').str[-1] #clean from '-'
            df['price'] = df['price'].str[:-3] #clean from 'kr'
            df['price'] = df['price'].str.replace('\xa0', '') #clean from '\xa0'
            if df['price'].str.contains('http').sum(): #clean from http
                df = df[~df['price'].str.contains('http')]
                
            #price to int
            try:
                df['price'] = df['price'].map(int)
                if len(df.loc[df['price'] < 100, 'price'])>0: #clean from untrust values
                    df.loc[df['price'] < 100, 'price'] =0
            except:
                print("can't make price int")

        except:
            print('problem with price descr')
    
    #for price_desc
    if 'price_desc' in df.columns:
        try:
            #trying to understend if is something to split
            df_pr = df['price_desc'].str.split(' ∙ ', expand=True) 
            df_pr_count = df_pr.iloc[0].count()#!!!! mistake--------------------------------------!!!!
            
            #if 2 items
            if df_pr_count == 2:
                df[['total_price', 'fellesutg']] = df_pr
                del df['price_desc']

                #fellestung cleaning
                try:
                    # clean from- :, -, kr, \xa0
                    df.loc[:, 'fellesutg'] = df['fellesutg'].str.split(':').str[-1].str.split('-').str[-1].str[:-3].str.replace('\xa0', '')
                    try:
                        df['fellesutg'].fillna(0, inplace=True) #fill None with 0
                        df.loc[:, 'fellesutg'] = df['fellesutg'].map(int) #make int
                    except:
                        print("can't make fellesutg int")
                        
                except:
                    print('problem with fellesutg cleaning')
            
            #if nothing to split, probably it's a total
            if df_pr_count == 1:
                df['total_price'] = df_pr
                del df['price_desc']
            
            #total_price cleaning
            try:
                # clean from- :, -, kr, \xa0
                df.loc[:, 'total_price'] = df['total_price'].str.split(':').str[-1].str.split('-').str[-1].str[:-3].str.replace('\xa0', '')
                try:
                    df['total_price'].fillna(0, inplace=True) #fill None with 0
                    df.loc[:, 'total_price'] = df['total_price'].map(int) #make int
                except:
                    print("can't make total_price int")
                    
            except:
                print('problem with total_price cleaning')
                
        except:
            print('problem with price_desc descr')

    #for r_type_amount
    if 'r_type_amount' in df.columns:
        try:
            #trying to understend if is something to split
            df_am = df['r_type_amount'].str.split(' ∙ ', expand=True)
            df_am_count = df_am.iloc[0].count() #!!!!!!!!!!! --------------- could give a mistake!!!!!!
            
            #if 2 items
            if df_am_count == 2:
                
                if df_am.iloc[:, -1].str.contains('Leilighet|Hus').sum(): #is it type
                    df[['owner?', 'type']] = df_am
                    del df['r_type_amount']
                
                elif df_am.iloc[:, -1].str.isdigit().sum(): #is it rooms amount
                    df[['type', 'rooms_amount']] = df_am
                    del df['r_type_amount']

            
            #if 3 items
            elif df_am_count == 3:
                df[['owner?', 'type', 'rooms_amount']] = df_am
                del df['r_type_amount']

            #clean 'rooms_amount' from str -'rooms' and make int
            if 'rooms_amount' in df.columns:
                df.loc[:, 'rooms_amount'] = df['rooms_amount'].str.split().str[0] #clean from str 'rooms'

                try:
                    df['rooms_amount'].fillna(0, inplace=True) #fill None with 0
                    df.loc[:, 'rooms_amount'] = df['rooms_amount'].map(int) #make int
                except:
                    print("can't make rooms_amount int")

            #more settings - sometimes nessesery
            df.loc[df['type'] == 'Garasje/Parker', ['type']] = 'Garasje/Parkering'
        
        except:
            print('problem with r_type_amount descr')
            
    #for square_metre
    if 'square_metre' in df.columns:
        try:
            if df['square_metre'].str.contains('http').sum(): #clean from http
                df = df[~df['square_metre'].str.contains('http')]
            df['square_metre'] = df['square_metre'].str.split().str[0] #clean from 'm2'
            df['square_metre'] = df['square_metre'].map(int) #make int
        
        except:
            print('problem with square_metre descr')
            
    #for visning
    if 'visning' in df.columns:
        try:
            #is there any links
            html_v = df['visning'].str.contains('http')
            if html_v.sum():
                df.loc[html_v, 'link'] = df.loc[html_v, 'visning']
                df.loc[html_v, 'visning'] = ''
            #clean from str - 'visning'
            df['visning'] = df['visning'].str.split(' - ').str[-1]
            
        except:
            print('problem with visning descr')
    
    return df
# Out:
# Overwriting cleaning.py

# %%
cleaning(all_data)
# Out:
#                                                                                                                      name  \
# 0             Kuben trinn 2 | 4 ledige leiligheter i sjøkanten i Damsgårdssundet | Takterrasse | Byggingen er godt i gang
# 1         Villa Høye - Urbant leilighetsprosjekt med spennende og historisk arkitektur på ærverdige Høyegaarden. 6 solgt!
# 4                        Kuben | Byggingen er godt i gang | Kun 3 ledige på kaipromenaden i Damsgårdssundet | Takterrasse
# 6  MØLLENESET - FANTASTISK BELIGGENHET VED STORE LUNGEGÅRDSVANN. 67 NYDELIGE OG ATTRAKTIVE LEILIGHETER! FÅ LEDIGE ENHETER
#
#                                        from                     address  \
# 0               KALAND & PARTNERS NYBYGG AS   Damsgårdsveien 91, Bergen
# 1  PrivatMegleren Vikebø & Jørgensen Nybygg  Gyldenprisveien 16, Bergen
# 4               KALAND & PARTNERS NYBYGG AS   Damsgårdsveien 91, Bergen
# 6                    Aktiv Prosjektmegling   Møllendalsveien 64, Bergen
#
#    square_metre     price               visning  \
# 0           115  11500000  Visning etter avtale
# 1            35   7700000    26. juli, kl 14:00
# 4            49  11300000  Visning etter avtale
# 6            64  11000000  Visning etter avtale
#
#                                                                                                                                            link  \
# 0  https://www.finn.no/eiendom/nybygg/prosjekt?finnkode=270267499&geoLocationName=Bergen&lat=60.3894&lon=5.3300&radius=3000&sort=PUBLISHED_DESC
# 1  https://www.finn.no/eiendom/nybygg/prosjekt?finnkode=307459500&geoLocationName=Bergen&lat=60.3894&lon=5.3300&radius=3000&sort=PUBLISHED_DESC
# 4  https://www.finn.no/eiendom/nybygg/prosjekt?finnkode=262346667&geoLocationName=Bergen&lat=60.3894&lon=5.3300&radius=3000&sort=PUBLISHED_DESC
# 6  https://www.finn.no/eiendom/nybygg/prosjekt?finnkode=309473760&geoLocationName=Bergen&lat=60.3894&lon=5.3300&radius=3000&sort=PUBLISHED_DESC
#
#   total_price           owner?       type
# 0    11512662  Eier (Selveier)  Leilighet
# 1     7707132            Andel  Leilighet
# 4    11312762  Eier (Selveier)  Leilighet
# 6    11000000  Eier (Selveier)  Leilighet

# %%
all_data['r_type_amount'].str.split(' ∙ ', expand=True).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'r_type_amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 all_data['r_type_amount'].str.split(' ∙ ', expand=True).count()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'r_type_amount'

# %%
all_data
# Out:
#                                                                                                                            0  \
# 0                 Tomt i ende av blindvei i et etablert boligfelt. Fantastisk utsikt og gode solforhold. Kort vei til "alt".
# 1   Nydelig beliggende byggeklar boligtomt i populære Sædalen - landlig og sentralt på en gang - gangavstand til barneskolen
# 2                 Heiane | Stor tomt med attraktiv beliggenhet, gode solforhold og utsikt over Banntjørna. Stort potensiale!
# 3              Ytre Arna - Tomt med god beliggenhet og nydelig utsikt. Rammetillatelse foreligger for enebolig med utleiedel
# 4             Unik byggeklar utsikts-tomt i Mathopen! IG gitt til å bygge et råtøft funkis hus på 349 m2! Sjøtomt medfølger!
# 5                                               STRAUMSGREND - Byggeklar tomt med rammetillatelse til oppføring av funkishus
# 6           Glasskaret | Stor tomt i populært område med utsikt, gode solforhold og nærhet til både Åsane og Bergen sentrum!
# 7                                                                                                     Utsiktstomt, Ytre Arna
# 8     Godvik | Flott tomt i naturskjønneomgivelser kort vei til skole og turmuligheter. Ca. 5 min unna Vestkanten Storsenter
# 9   Stor hellende solrik tomt med en fantastisk storslagen utsikt mot sørvest. Man ser til Austevoll i det fjerne. Bør sees!
# 10  To solrike tomter på til sammen 1387m². 7 minutter til Kleppestø senter. Området regulert til bolig. Gangavstand til sjø
# 11                 Stor boligtomt med flott og sentral beliggenhet i barnevennlig område! Gode solforhold og nydelig utsikt.
# 12    Bygge hus? Nydelig beliggende boligtomt  i Sædalen - barnevennlig nær barneskole - super utsikt over fjell og nærmiljø
# 13  Godvik - Boligtomt på 7,7 mål regulert til 5 eneboliger. Attraktiv og barnevennlig beliggenhet. Kort vei til Vestkanten.
# 14         Spennende tomt bestående av to bruksnummer - Attraktiv beliggenhet i Skarholmen | Totalt 2014,5 m² - Bud vurderes
# 15                                               GODVIK - Tomt med meget sentral beliggenhet i Godvik -  Gangavstand til alt
# 16                                               FLORVÅG - Stor tomt med flott utsikt utover byfjorden  - Regulert til bolig
# 17                   Kvernhusdalen - Stor boligtomt som er regulert for leilighetsbygg med 12 enheter  - Sentral beliggenhet
# 18                                                                              Flott sjøtomt beliggende i Leirvika i Godvik
# 19       Flott tomt i nyetablert boligområde | Meget barnevennlig | Sentral og attraktiv beliggenhet med kort vei til "alt"|
# 20                               Unik mulighet. Nydelig utsiktstomt sentralt i Kleppestø. Sjeldent gode solforhold. Må sees.
# 21                                                         Utsiktstomt i Ytre Arna | Avsatt til boligformål i kommunedelplan
# 22                                                       Tomt ved Storetveitvegen i byfortettingssone (BY) på hele 1450 kvm.
# 23                                                                                Sjelden og sentral tomt i Birkelundsbakken
# 24         Sentral og attraktiv boligtomt i Åsane - populært og barnevennlig område - gode sol og utsiktsforhold - Bør sees!
#
#                                                        1  \
# 0                                EiendomsMegler 1 Bergen
# 1                                    Privatmegleren Vest
# 2                     EIE eiendomsmegling Bergen Sentrum
# 3                                                 Privat
# 4      Kaland & Partners - Vestkanten Eiendomsmegling AS
# 5                     Eiendomsmegler Vest Bergen Sentrum
# 6                     EIE eiendomsmegling Bergen Sentrum
# 7                                                 Privat
# 8                        EIE eiendomsmegling Bergen Vest
# 9                                     PrivatMegleren Syd
# 10                                   Nordvik Bergen Vest
# 11  Kaland & Partners - Torgallmenningen Eiendomsmegling
# 12                                   Privatmegleren Vest
# 13  Kaland & Partners - Torgallmenningen Eiendomsmegling
# 14                             Eiendomsmegler Vest Askøy
# 15                             Eiendomsmegler Vest Askøy
# 16                             Eiendomsmegler Vest Askøy
# 17                             Eiendomsmegler Vest Askøy
# 18                                Fana Sparebank Eiendom
# 19                    EiendomsMegler 1 Askøy og Øygarden
# 20                    EiendomsMegler 1 Askøy og Øygarden
# 21                                    PrivatMegleren Syd
# 22                               Proaktiv Småstrandgaten
# 23                                             Coplan AS
# 24          Kaland & Partners - Vestland Eiendomsmegling
#
#                                          2         3  \
# 0             Straumsåsen 38, Straumsgrend    733 m²
# 1                 Rinddalen tomt 2, Bergen    705 m²
# 2                      Tomt heiane, Nyborg  1 068 m²
# 3             Peter Jebsens veg, Ytre Arna    593 m²
# 4                Storingavika 96, Mathopen  1 395 m²
# 5             Straumsåsen 20, Straumsgrend    896 m²
# 6              Tomt Glasskaret, Øvre Ervik    664 m²
# 7                  Sætrefjellet, Ytre Arna  1 127 m²
# 8                     Alvøveien 71, Godvik    827 m²
# 9         Rosenlundveien 50, Fyllingsdalen  1 530 m²
# 10                   Tomt Follese, Follese  1 387 m²
# 11  Vestre Drotningsvik 56A (Tomt), Godvik    603 m²
# 12                       Rinddalen, Bergen    794 m²
# 13                Tomt Godvikveien, Godvik  7 731 m²
# 14             Tomt Skarholmen, Strusshamn  2 015 m²
# 15                     Tomt Godvik, Godvik    833 m²
# 16                   Tomt Florvåg, Florvåg  2 322 m²
# 17           Tomt Kvernhusdalen, Kleppestø  2 040 m²
# 18                        Leirvika, Godvik     80 m²
# 19            Gunnlafjellet 44, Strusshamn    743 m²
# 20                      Solhola, Kleppestø    797 m²
# 21            Peter Jebsens veg, Ytre Arna    684 m²
# 22            Storetveitvegen 168, Paradis  1 451 m²
# 23            Birkelundsbakken 17, Paradis  1 235 m²
# 24                         Åslia 61, Ulset  1 070 m²
#
#                                 4                              5  \
# 0                    1 990 000 kr        Totalpris: 2 040 920 kr
# 1                    1 600 000 kr        Totalpris: 1 648 842 kr
# 2                    2 200 000 kr        Totalpris: 2 269 020 kr
# 3                      750 000 kr          Totalpris: 770 000 kr
# 4                    4 990 000 kr        Totalpris: 5 130 992 kr
# 5                    2 990 000 kr        Totalpris: 3 065 920 kr
# 6                    1 290 000 kr        Totalpris: 1 323 620 kr
# 7                      990 000 kr  https://www.finn.no/252915944
# 8                    1 750 000 kr        Totalpris: 1 795 120 kr
# 9                    2 890 000 kr        Totalpris: 2 971 092 kr
# 10                     850 000 kr          Totalpris: 880 092 kr
# 11                   1 600 000 kr        Totalpris: 1 650 242 kr
# 12                   1 600 000 kr        Totalpris: 1 648 842 kr
# 13                   5 500 000 kr        Totalpris: 5 653 742 kr
# 14                   2 000 000 kr        Totalpris: 2 064 270 kr
# 15                   1 200 000 kr        Totalpris: 1 244 270 kr
# 16                   3 600 000 kr        Totalpris: 3 704 270 kr
# 17                   5 900 000 kr        Totalpris: 6 061 770 kr
# 18                     490 000 kr          Totalpris: 516 720 kr
# 19                   1 890 000 kr        Totalpris: 1 938 420 kr
# 20                   1 950 000 kr        Totalpris: 1 999 920 kr
# 21                     790 000 kr          Totalpris: 811 092 kr
# 22  https://www.finn.no/249810196                           None
# 23                     750 000 kr          Totalpris: 776 500 kr
# 24                   2 980 000 kr        Totalpris: 3 065 742 kr
#
#                                 6                              7
# 0   https://www.finn.no/310587044                           None
# 1   https://www.finn.no/309630935                           None
# 2   https://www.finn.no/309134531                           None
# 3   https://www.finn.no/170864459                           None
# 4   https://www.finn.no/307552298                           None
# 5   https://www.finn.no/307439152                           None
# 6   https://www.finn.no/307003470                           None
# 7                            None                           None
# 8   https://www.finn.no/304239563                           None
# 9   https://www.finn.no/302964781                           None
# 10  https://www.finn.no/298783622                           None
# 11  https://www.finn.no/300383463                           None
# 12  https://www.finn.no/294386127                           None
# 13  https://www.finn.no/285617802                           None
# 14  https://www.finn.no/283142141                           None
# 15  https://www.finn.no/278055306                           None
# 16  https://www.finn.no/274111147                           None
# 17  https://www.finn.no/272116570                           None
# 18                Eier (Selveier)  https://www.finn.no/263244749
# 19  https://www.finn.no/262172217                           None
# 20  https://www.finn.no/252426443                           None
# 21  https://www.finn.no/250879370                           None
# 22                           None                           None
# 23  https://www.finn.no/163732475                           None
# 24  https://www.finn.no/156832367                           None

# %%
#saving to csv
leie.to_csv('leie_120723.csv', sep=',', index=False, encoding='utf-8-sig')
